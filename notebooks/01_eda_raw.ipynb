# %% [markdown]
# # EDA Raw

# %% [markdown]
# ## 載入套件與基本設定

# %%
import pandas as pd

# %% [markdown]
# ## 載入資料

# %%
companies_df = pd.read_csv("../data/raw/us_companies.csv")
companies_df.head()
# Out:
#   Ticker  SimFinId Company Name  IndustryId ISIN  \
# 0    NaN  18847915          NaN         NaN  NaN
# 1    NaN  18538670          NaN         NaN  NaN
# 2    NaN  18657366          NaN         NaN  NaN
# 3    NaN  18667300          NaN         NaN  NaN
# 4    NaN  18692750          NaN         NaN  NaN
#
#    End of financial year (month)  Number Employees Business Summary Market  \
# 0                            NaN               NaN              NaN     us
# 1                            NaN               NaN              NaN     us
# 2                            NaN               NaN              NaN     us
# 3                            NaN               NaN              NaN     us
# 4                            NaN               NaN              NaN     us
#
#          CIK Main Currency
# 0  1769731.0           USD
# 1  1734107.0           USD
# 2  1899830.0           USD
# 3  1178819.0           USD
# 4  1997711.0           USD

# %%
income_statement_df = pd.read_csv("../data/raw/us_income_statement.csv")
income_statement_df.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2019            Q4  2019-10-31
# 1      A     45846      USD         2020            Q1  2020-01-31
# 2      A     45846      USD         2020            Q2  2020-04-30
# 3      A     45846      USD         2020            Q3  2020-07-31
# 4      A     45846      USD         2020            Q4  2020-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2019-08-30     309000000.0       313000000.0  ...
# 1   2020-03-03    2021-03-02     310000000.0       313000000.0  ...
# 2   2020-06-01    2021-06-01     309000000.0       312000000.0  ...
# 3   2020-09-01    2021-09-01     309000000.0       312000000.0  ...
# 4   2020-12-18    2021-09-01     308000000.0       311000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -19000000.0            -15000000.0
# 1                    4000000.0            -17000000.0
# 2                   19000000.0            -17000000.0
# 3                  -11000000.0            -18000000.0
# 4                  -16000000.0            -18000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                 231000000.0                      NaN             231000000
# 1                 219000000.0                      NaN             219000000
# 2                 121000000.0                      NaN             121000000
# 3                 219000000.0                      NaN             219000000
# 4                 283000000.0                      NaN             283000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                        -37000000.0
# 1                        -22000000.0
# 2                        -20000000.0
# 3                        -20000000.0
# 4                        -61000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 194000000                               NaN
# 1                                 197000000                               NaN
# 2                                 101000000                               NaN
# 3                                 199000000                               NaN
# 4                                 222000000                               NaN
#
#    Net Income  Net Income (Common)
# 0   194000000            194000000
# 1   197000000            197000000
# 2   101000000            101000000
# 3   199000000            199000000
# 4   222000000            222000000
#
# [5 rows x 28 columns]

# %%
balance_sheet_df = pd.read_csv("../data/raw/us_balance_sheet.csv")
balance_sheet_df.head()
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2019            Q4  2019-10-31
# 1      A     45846      USD         2020            Q1  2020-01-31
# 2      A     45846      USD         2020            Q2  2020-04-30
# 3      A     45846      USD         2020            Q3  2020-07-31
# 4      A     45846      USD         2020            Q4  2020-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2019-12-19    2020-12-18     309000000.0       313000000.0  ...
# 1   2020-03-03    2020-03-03     310000000.0       313000000.0  ...
# 2   2020-06-01    2020-06-01     309000000.0       312000000.0  ...
# 3   2020-09-01    2020-09-01     309000000.0       312000000.0  ...
# 4   2020-12-18    2021-12-17     308000000.0       311000000.0  ...
#
#    Short Term Debt  Total Current Liabilities  Long Term Debt  \
# 0      616000000.0               2.080000e+09    1.791000e+09
# 1      675000000.0               1.892000e+09    1.787000e+09
# 2      700000000.0               1.945000e+09    1.788000e+09
# 3       40000000.0               1.314000e+09    2.283000e+09
# 4       75000000.0               1.467000e+09    2.284000e+09
#
#    Total Noncurrent Liabilities  Total Liabilities  \
# 0                  2.624000e+09       4.704000e+09
# 1                  2.761000e+09       4.653000e+09
# 2                  2.742000e+09       4.687000e+09
# 3                  3.251000e+09       4.565000e+09
# 4                  3.287000e+09       4.754000e+09
#
#    Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                5.280000e+09             NaN
# 1                                5.296000e+09             NaN
# 2                                5.291000e+09             NaN
# 3                                5.327000e+09             NaN
# 4                                5.314000e+09             NaN
#
#    Retained Earnings  Total Equity  Total Liabilities & Equity
# 0        -18000000.0  4.748000e+09                  9452000000
# 1         73000000.0  4.848000e+09                  9501000000
# 2         15000000.0  4.768000e+09                  9455000000
# 3        130000000.0  4.981000e+09                  9546000000
# 4         81000000.0  4.873000e+09                  9627000000
#
# [5 rows x 30 columns]

# %%
share_prices_df = pd.read_csv("../data/raw/us_share_prices.csv")
share_prices_df.head()
# Out:
#   Ticker  SimFinId        Date   Open   High    Low  Close  Adj. Close  \
# 0      A     45846  2019-08-07  66.87  68.27  66.48  67.97       65.14
# 1      A     45846  2019-08-08  68.43  69.51  68.10  69.49       66.60
# 2      A     45846  2019-08-09  68.94  68.94  67.82  68.64       65.79
# 3      A     45846  2019-08-12  68.22  68.38  66.50  66.63       63.86
# 4      A     45846  2019-08-13  66.91  68.78  66.50  67.64       64.83
#
#     Volume  Dividend  Shares Outstanding
# 0  2172854       NaN         310000000.0
# 1  2014261       NaN         310000000.0
# 2  1866212       NaN         310000000.0
# 3  2294418       NaN         310000000.0
# 4  3170549       NaN         310000000.0
