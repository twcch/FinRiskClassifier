# %% [markdown]
# # EDA Raw

# %% [markdown]
# ## 載入套件與基本設定

# %%
import os
os.chdir("..")

# %%
import pandas as pd

# %% [markdown]
# ## 載入資料

# %%
companies_df = pd.read_csv("data/raw/us_companies.csv")
companies_df.head()
# Out:
#    SimFinId                                       Company Name  IndustryId  \
# 0     45846                           AGILENT TECHNOLOGIES INC    106001.0
# 1   1333027                                       Li Auto Inc.         NaN
# 2    367153                                         Alcoa Corp    110004.0
# 3   7962652                       Ares Acquisition Corporation    104002.0
# 4  18959140  Artius II Acquisition Inc. Class A Ordinary Sh...    104002.0
#
#            ISIN  End of financial year (month)  Number Employees  \
# 0  US00846U1016                           10.0           16400.0
# 1           NaN                           12.0               NaN
# 2  US0138721065                           12.0           12900.0
# 3  US0003071083                           12.0               NaN
# 4  KYG0509J1076                           12.0               NaN
#
#                                     Business Summary Market        CIK  \
# ...

# %%
income_statement_df = pd.read_csv("data/raw/us_income_statement.csv")
income_statement_df.head()
# Out:
#    SimFinId Currency  Fiscal Year Fiscal Period Publish Date Restated Date  \
# 0     45846      USD         2019            Q4   2019-12-19    2019-08-30
# 1     45846      USD         2020            Q1   2020-03-03    2021-03-02
# 2     45846      USD         2020            Q2   2020-06-01    2021-06-01
# 3     45846      USD         2020            Q3   2020-09-01    2021-09-01
# 4     45846      USD         2020            Q4   2020-12-18    2021-09-01
#
#    Shares (Basic)  Shares (Diluted)       Revenue  Cost of Revenue  ...  \
# 0     309000000.0       313000000.0  1.367000e+09     -630000000.0  ...
# 1     310000000.0       313000000.0  1.357000e+09     -634000000.0  ...
# 2     309000000.0       312000000.0  1.238000e+09     -581000000.0  ...
# 3     309000000.0       312000000.0  1.261000e+09     -592000000.0  ...
# 4     308000000.0       311000000.0  1.483000e+09     -695000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# ...

# %%
balance_sheet_df = pd.read_csv("data/raw/us_balance_sheet.csv")
balance_sheet_df.head()
# Out:
#    SimFinId Currency  Fiscal Year Fiscal Period Publish Date Restated Date  \
# 0     45846      USD         2019            Q4   2019-12-19    2020-12-18
# 1     45846      USD         2020            Q1   2020-03-03    2020-03-03
# 2     45846      USD         2020            Q2   2020-06-01    2020-06-01
# 3     45846      USD         2020            Q3   2020-09-01    2020-09-01
# 4     45846      USD         2020            Q4   2020-12-18    2021-12-17
#
#    Shares (Basic)  Shares (Diluted)  \
# 0     309000000.0       313000000.0
# 1     310000000.0       313000000.0
# 2     309000000.0       312000000.0
# 3     309000000.0       312000000.0
# 4     308000000.0       311000000.0
#
#    Cash, Cash Equivalents & Short Term Investments  \
# 0                                     1.382000e+09
# 1                                     1.226000e+09
# 2                                     1.324000e+09
# 3                                     1.358000e+09
# ...

# %%
share_prices_df = pd.read_csv("data/raw/us_share_prices.csv")
share_prices_df.head()
# Out:
#    SimFinId   Open   High    Low  Close  Adj. Close   Volume  Dividend  \
# 0     45846  66.84  67.17  65.66  65.86       63.25  3273115       NaN
# 1     45846  66.41  67.68  66.04  67.66       64.98  2436228       NaN
# 2     45846  66.87  68.27  66.48  67.97       65.28  2172854       NaN
# 3     45846  68.43  69.51  68.10  69.49       66.74  2014261       NaN
# 4     45846  68.94  68.94  67.82  68.64       65.92  1866212       NaN
#
#    Shares Outstanding
# 0         310000000.0
# 1         310000000.0
# 2         310000000.0
# 3         310000000.0
# 4         310000000.0
